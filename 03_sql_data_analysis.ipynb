# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
GOLD_DIR=r"C:\Users\gh81a\Desktop\PythonProjectnoura\noura_foods_project\data\gold"

# %%
files_to_load = ["Fact_Sales.csv", "Dim_Customers.csv", "Dim_Products.csv",
                 "Dim_Stores.csv", "Dim_Campaigns.csv", "Dim_Economy.csv"]

# %%
# !pip install pymysql sqlalchemy
# Out:
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: sqlalchemy in C:\Users\gh81a\data_env\Lib\site-packages (2.0.49)
# Requirement already satisfied: greenlet>=1 in C:\Users\gh81a\data_env\Lib\site-packages (from sqlalchemy) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\gh81a\data_env\Lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
engine = create_engine("mysql+pymysql://root:Ghazal818283@localhost:3306/noura_foods")

# %%
for file in files_to_load:
    table_name = file.replace(".csv", "")
    df = pd.read_csv(os.path.join(GOLD_DIR, file))
    df.to_sql(table_name, engine, if_exists='replace,index=False)
# Out:
# C:\Users\gh81a\AppData\Local\Temp\ipykernel_2688\3797795906.py:4: UserWarning: The provided table name 'Fact_Sales' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(table_name, engine, if_exists='replace', index=False)
# C:\Users\gh81a\AppData\Local\Temp\ipykernel_2688\3797795906.py:4: UserWarning: The provided table name 'Dim_Customers' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(table_name, engine, if_exists='replace', index=False)
# C:\Users\gh81a\AppData\Local\Temp\ipykernel_2688\3797795906.py:4: UserWarning: The provided table name 'Dim_Products' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(table_name, engine, if_exists='replace', index=False)
# C:\Users\gh81a\AppData\Local\Temp\ipykernel_2688\3797795906.py:4: UserWarning: The provided table name 'Dim_Stores' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(table_name, engine, if_exists='replace', index=False)
# C:\Users\gh81a\AppData\Local\Temp\ipykernel_2688\3797795906.py:4: UserWarning: The provided table name 'Dim_Campaigns' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(table_name, engine, if_exists='replace', index=False)
# C:\Users\gh81a\AppData\Local\Temp\ipykernel_2688\3797795906.py:4: UserWarning: The provided table name 'Dim_Economy' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(table_name, engine, if_exists='replace', index=False)
